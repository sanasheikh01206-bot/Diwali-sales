# %% [markdown]
#  import python libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
#  import csv file

# %%
df = pd.read_csv("Diwali Sales Data.csv",encoding = "unicode_escape")

# %%
df.shape
# Out:
# (11251, 15)

# %%
df.size
# Out:
# 168765

# %%
df.ndim
# Out:
# 2

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11251 entries, 0 to 11250
# Data columns (total 15 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   User_ID           11251 non-null  int64
#  1   Cust_name         11251 non-null  object
#  2   Product_ID        11251 non-null  object
#  3   Gender            11251 non-null  object
#  4   Age Group         11251 non-null  object
#  5   Age               11251 non-null  int64
#  6   Marital_Status    11251 non-null  int64
#  7   State             11251 non-null  object
#  8   Zone              11251 non-null  object
#  9   Occupation        11251 non-null  object
#  10  Product_Category  11251 non-null  object
#  11  Orders            11251 non-null  int64
#  12  Amount            11239 non-null  float64
#  13  Status            0 non-null      float64
#  14  unnamed1          0 non-null      float64
# dtypes: float64(3), int64(4), object(8)
# memory usage: 1.3+ MB

# %%
df.head()
# Out:
#    User_ID  Cust_name Product_ID Gender Age Group  Age  Marital_Status  \
# 0  1002903  Sanskriti  P00125942      F     26-35   28               0
# 1  1000732     Kartik  P00110942      F     26-35   35               1
# 2  1001990      Bindu  P00118542      F     26-35   35               1
# 3  1001425     Sudevi  P00237842      M      0-17   16               0
# 4  1000588       Joni  P00057942      M     26-35   28               1
#
#             State      Zone       Occupation Product_Category  Orders  \
# 0     Maharashtra   Western       Healthcare             Auto       1
# 1  Andhra Pradesh  Southern             Govt             Auto       3
# 2   Uttar Pradesh   Central       Automobile             Auto       3
# 3       Karnataka  Southern     Construction             Auto       2
# 4         Gujarat   Western  Food Processing             Auto       2
#
#     Amount  Status  unnamed1
# 0  23952.0     NaN       NaN
# 1  23934.0     NaN       NaN
# ...

# %% [markdown]
# drop unrelated columns

# %%
df.isna().sum()
# Out:
# User_ID                 0
# Cust_name               0
# Product_ID              0
# Gender                  0
# Age Group               0
# Age                     0
# Marital_Status          0
# State                   0
# Zone                    0
# Occupation              0
# Product_Category        0
# Orders                  0
# Amount                 12
# Status              11251
# unnamed1            11251
# dtype: int64

# %%
df.drop(columns = ["unnamed1","Status"],axis = 1,inplace = True)

# %% [markdown]
# check for null values

# %%
df.isna().sum()
# Out:
# User_ID              0
# Cust_name            0
# Product_ID           0
# Gender               0
# Age Group            0
# Age                  0
# Marital_Status       0
# State                0
# Zone                 0
# Occupation           0
# Product_Category     0
# Orders               0
# Amount              12
# dtype: int64

# %% [markdown]
# drop null values

# %%
df.dropna(inplace = True)

# %%
df.isna().sum()
# Out:
# User_ID             0
# Cust_name           0
# Product_ID          0
# Gender              0
# Age Group           0
# Age                 0
# Marital_Status      0
# State               0
# Zone                0
# Occupation          0
# Product_Category    0
# Orders              0
# Amount              0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 11239 entries, 0 to 11250
# Data columns (total 13 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   User_ID           11239 non-null  int64
#  1   Cust_name         11239 non-null  object
#  2   Product_ID        11239 non-null  object
#  3   Gender            11239 non-null  object
#  4   Age Group         11239 non-null  object
#  5   Age               11239 non-null  int64
#  6   Marital_Status    11239 non-null  int64
#  7   State             11239 non-null  object
#  8   Zone              11239 non-null  object
#  9   Occupation        11239 non-null  object
#  10  Product_Category  11239 non-null  object
#  11  Orders            11239 non-null  int64
#  12  Amount            11239 non-null  float64
# dtypes: float64(1), int64(4), object(8)
# memory usage: 1.2+ MB

# %% [markdown]
# change the data type

# %%
df["Amount"] = df["Amount"].astype("int")

# %%
df["Amount"].dtype
# Out:
# dtype('int64')

# %%
df.columns
# Out:
# Index(['User_ID', 'Cust_name', 'Product_ID', 'Gender', 'Age Group', 'Age',
#        'Marital_Status', 'State', 'Zone', 'Occupation', 'Product_Category',
#        'Orders', 'Amount'],
#       dtype='object')

# %% [markdown]
# rename column

# %%
df.rename(columns = {"Marital_Status":"Matrimonial_Status"})
# Out:
#        User_ID    Cust_name Product_ID Gender Age Group  Age  \
# 0      1002903    Sanskriti  P00125942      F     26-35   28
# 1      1000732       Kartik  P00110942      F     26-35   35
# 2      1001990        Bindu  P00118542      F     26-35   35
# 3      1001425       Sudevi  P00237842      M      0-17   16
# 4      1000588         Joni  P00057942      M     26-35   28
# ...        ...          ...        ...    ...       ...  ...
# 11246  1000695      Manning  P00296942      M     18-25   19
# 11247  1004089  Reichenbach  P00171342      M     26-35   33
# 11248  1001209        Oshin  P00201342      F     36-45   40
# 11249  1004023       Noonan  P00059442      M     36-45   37
# 11250  1002744      Brumley  P00281742      F     18-25   19
#
#        Matrimonial_Status           State      Zone       Occupation  \
# 0                       0     Maharashtra   Western       Healthcare
# 1                       1  Andhra Pradesh  Southern             Govt
# ...

# %% [markdown]
# using describe method for description of the data in the form of DataFrame

# %%
(df.describe()).round(2)
# Out:
#           User_ID       Age  Marital_Status    Orders    Amount
# count    11239.00  11239.00        11239.00  11239.00  11239.00
# mean   1003003.52     35.41            0.42      2.49   9453.61
# std       1716.04     12.75            0.49      1.11   5222.36
# min    1000001.00     12.00            0.00      1.00    188.00
# 25%    1001491.50     27.00            0.00      2.00   5443.00
# 50%    1003064.00     33.00            0.00      2.00   8109.00
# 75%    1004426.50     43.00            1.00      3.00  12675.00
# max    1006040.00     92.00            1.00      4.00  23952.00

# %% [markdown]
# using describe for specific functions

# %%
(df[["Age","Orders","Amount"]].describe()).round(2)
# Out:
#             Age    Orders    Amount
# count  11239.00  11239.00  11239.00
# mean      35.41      2.49   9453.61
# std       12.75      1.11   5222.36
# min       12.00      1.00    188.00
# 25%       27.00      2.00   5443.00
# 50%       33.00      2.00   8109.00
# 75%       43.00      3.00  12675.00
# max       92.00      4.00  23952.00

# %% [markdown]
# ### Exploratory Data Analysis

# %% [markdown]
#  # gender

# %%
ax = sns.countplot(data = df, x = "Gender", hue = "Gender", dodge = False, legend = False, palette = "icefire")
plt.show()
for bars in ax.containers:
    ax.bar_label(bars)

# %% [markdown]
#  ploting a bar chart of gender vs total amount

# %%
sales_gen = df.groupby(["Gender"],as_index = False)["Amount"].sum().sort_values(by = "Amount",ascending = False)
sns.barplot(data = sales_gen,x = "Gender", y = "Amount", hue = "Gender", dodge = False, legend = False, palette = "flare")
# Out:
# <Axes: xlabel='Gender', ylabel='Amount'>

# %%
# from the above graph we can see that most of the buyers are female and the purchasing power of females are greater than men

# %% [markdown]
#  # Age

# %%
ax = sns.countplot(x = "Age Group",data = df,hue = "Gender")
plt.show()
for bars in ax.containers:
    ax.bar_label(bars)

# %% [markdown]
# Total amount & Age group

# %%
sales_age = df.groupby(["Age Group"],as_index = False)["Amount"].sum().sort_values(by = "Amount",ascending = False)
sns.barplot(data=sales_age, x="Age Group", y="Amount", hue="Age Group", palette="tab10", dodge=False, legend=False)
# Out:
# <Axes: xlabel='Age Group', ylabel='Amount'>

# %%
# from the above graph we can see that most of the buyers are between the ages of 26-35

# %% [markdown]
# # State

# %% [markdown]
# total number of orders from top 10 states

# %% [markdown]
# total amount/sales in each state

# %%
sales_state = df.groupby(['State'], as_index=False)['Amount'].sum().sort_values(by='Amount', ascending=False).head(10)
plt.figure(figsize = (15,6))
sns.barplot(data = sales_state,y = "Amount",x = "State",legend = False,dodge = False,hue = "State", palette = "Set3")
plt.xticks(rotation = 30)
plt.show()

# %%
# from the above graph we can see that most of the of the orders/total sales amount  are from the state of Uttar pradesh , Maharastra & Karnataka

# %% [markdown]
# # Marital Status

# %%
plt.figure(figsize=(8,5))
ax = sns.countplot(data=df, x='Marital_Status', hue='Marital_Status', palette='Set2', dodge=False, legend=False)

# %%
ax = sns.countplot(data = df, x = 'Marital_Status',dodge = False,palette = "mako",legend = False,hue = 'Marital_Status' )
for bars in ax.containers:
    ax.bar_label(bars)

# %%
sales_state = df.groupby(['Marital_Status', 'Gender'], as_index=False)['Amount'].sum().sort_values(by='Amount', ascending=False)
sns.barplot(data = sales_state, x = 'Marital_Status',y= 'Amount', hue='Gender')
# Out:
# <Axes: xlabel='Marital_Status', ylabel='Amount'>

# %%
# from the above graph we can see that most of the buyers are married women and they have high purchasing power

# %% [markdown]
# # Occupation

# %%
ax = sns.countplot(x = "Occupation", data = df, dodge = False, hue = "Occupation",legend = False,palette = "tab20")
plt.xticks(rotation = 90)
for bars in ax.containers:
    ax.bar_label(bars)

# %%
sales_state = df.groupby(["Occupation"],as_index = False)["Amount"].sum().sort_values(by = "Amount",ascending = False)
plt.figure(figsize = (15,5))
plt.xticks(rotation = 30)
sns.barplot(data = sales_state, x = "Occupation", y = "Amount", dodge = False, hue = "Occupation",legend = False, palette = "Paired")
# Out:
# <Axes: xlabel='Occupation', ylabel='Amount'>

# %%
# we can see that most of the buyers are from IT , Healthcare, Aviation section

# %% [markdown]
# # Product category

# %%
plt.figure(figsize = (15,5))
ax = sns.countplot(data = df,x = "Product_Category", hue = "Product_Category", dodge = False, legend = False, palette = "icefire")
plt.xticks(rotation = 45)
plt.show()
for bars in ax.containers:
    ax.bar_label(bars)

# %%
sales_state = df.groupby(["Product_Category"],as_index = False)["Amount"].sum().sort_values(by ="Product_Category",ascending = False).head(10)
plt.figure(figsize = (15,4))
plt.xticks(rotation = 30)
sns.barplot(data = sales_state,x = "Product_Category",y = "Amount",hue = "Product_Category", dodge = False, legend = False, palette = "colorblind")
# Out:
# <Axes: xlabel='Product_Category', ylabel='Amount'>

# %%
# from the above graph we can see that most of the sold products are from food, clothing and electronic category

# %%
sales_state = df.groupby(["Product_ID"],as_index = False)["Orders"].sum().sort_values(by = "Orders",ascending = False).head(10)
plt.figure(figsize = (15,5))
plt.xticks(rotation = 30)
sns.barplot(data = sales_state,y = "Orders",x = "Product_ID",hue = "Product_ID", dodge = False, legend = False, palette = "muted")
plt.show()

# %% [markdown]
# # Conclusion

# %% [markdown]
# #### married women age group 23-34 yrs from UP, Maharastro, Karnataka working in IT, Helthcare & Aviation are more likely to buy product from food, clothing & Electronics Category
